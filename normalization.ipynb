# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("normalization_wine_data.csv",usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']
df.head()
# Out:
#    Class label  Alcohol  Malic acid
# 0            1    13.20        1.78
# 1            1    13.16        2.36
# 2            1    14.37        1.95
# 3            1    13.24        2.59
# 4            1    14.20        1.76

# %%
sns.kdeplot(df["Alcohol"])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df["Malic acid"])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,:],df["Class label"],test_size=0.2,random_state=0)

# %%
X_train.shape,X_test.shape
# Out:
# ((141, 3), (36, 3))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(X_train) 
X_train_scaled = scaler.transform(X_train) 
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns = X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns= X_test.columns)

# %%
np.round(X_train.describe())
# Out:
#        Class label  Alcohol  Malic acid
# count        141.0    141.0       141.0
# mean           2.0     13.0         2.0
# std            1.0      1.0         1.0
# min            1.0     11.0         1.0
# 25%            1.0     12.0         2.0
# 50%            2.0     13.0         2.0
# 75%            3.0     14.0         3.0
# max            3.0     15.0         6.0

# %%
X_train_scaled.describe()
# Out:
#        Class label     Alcohol  Malic acid
# count   141.000000  141.000000  141.000000
# mean      0.489362    0.521944    0.296457
# std       0.389451    0.210509    0.231149
# min       0.000000    0.000000    0.000000
# 25%       0.000000    0.352151    0.144603
# 50%       0.500000    0.543011    0.201629
# 75%       1.000000    0.696237    0.454175
# max       1.000000    1.000000    1.000000

# %%
#we can see the values are between 0 and 1

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("before scalling")
sns.kdeplot(X_train["Alcohol"],ax=ax1)
sns.kdeplot(X_train["Malic acid"],ax=ax1)

ax2.set_title("before scalling")
sns.kdeplot(X_train_scaled["Alcohol"],ax=ax2)
sns.kdeplot(X_train_scaled["Malic acid"],ax=ax2)
# Out:
# <Axes: title={'center': 'before scalling'}, xlabel='Alcohol', ylabel='Density'>
